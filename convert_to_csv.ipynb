# %%
import pandas as pd

# %%
pd.read_excel('corpus.xlsx', index_col = 0).to_csv("corpus.csv", header = True)

# %%
pd.read_csv('corpus.csv', header = 0, index_col = 0)
# Out:
#                                       urn  \
# 0     URN:NBN:no-nb_digibok_2011081905042
# 1     URN:NBN:no-nb_digibok_2011021403012
# 2     URN:NBN:no-nb_digibok_2013062138046
# 3     URN:NBN:no-nb_digibok_2010041903042
# 4     URN:NBN:no-nb_digibok_2018041148085
# ...                                   ...
# 2684  URN:NBN:no-nb_digibok_2014112007633
# 2685  URN:NBN:no-nb_digibok_2011021403031
# 2686  URN:NBN:no-nb_digibok_2008100804066
# 2687  URN:NBN:no-nb_digibok_2016070748006
# 2688  URN:NBN:no-nb_digibok_2018090548001
#
#                                                   title  \
# 0                                       Raskt og enkelt
# 1                                        Ingers kokebok
# 2                               Sunne retter uten kjøtt
# 3                   Tilbehør til kjøtt, fisk og fjærkre
# 4                                              Kinesisk
# ...                                                 ...
# 2684                                 Mat på 15 minutter
# ...
